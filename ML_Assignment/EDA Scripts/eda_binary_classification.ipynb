# %% [markdown]
# ### Titanic Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# Display basic info
print(df.info())
print(df.describe())
print(df.isnull().sum())

# Visualize missing values
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.show()

# Distribution of target variable (Survived)
sns.countplot(x='Survived', data=df, hue='Survived', palette='coolwarm', legend=False)
plt.show()

# Correlation heatmap (only numeric columns)
numeric_df = df.select_dtypes(include=['number'])
plt.figure(figsize=(10,8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# Save cleaned dataset
df.dropna(inplace=True)
df.to_csv("E:\Projects\Ml_ops\ML_Assignment\EDA Scripts\Datasets\cleaned_titanic.csv", index=False)
# Out:
# <>:30: SyntaxWarning: invalid escape sequence '\P'
# <>:30: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\nayan\AppData\Local\Temp\ipykernel_632\1775883977.py:30: SyntaxWarning: invalid escape sequence '\P'
#   df.to_csv("E:\Projects\Ml_ops\ML_Assignment\EDA Scripts\Datasets\cleaned_titanic.csv", index=False)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
# ...
